# %%
# 读取环境变量
import os
frontAddress = os.environ.get('CTP_FRONT_ADDRESS')
mdFrontAddress = os.environ.get('CTP_MD_FRONT_ADDRESS')
brokerID = os.environ.get('CTP_BROKER_ID')
userID = os.environ.get('CTP_USER_ID')
password = os.environ.get('CTP_PASSWORD')
assert frontAddress and mdFrontAddress and brokerID and userID and password

# %%
from pyctp import Trader,Md,struct,callback
from time import sleep
from pandas import DataFrame
from pandas.io.excel import ExcelWriter

result = []
flag = []
def OnRspQryInstrument(**kwargs):
    result.append(kwargs['Data'])
    if kwargs['IsLast'] == True:
        flag.append(1)

trader = Trader(frontAddress,brokerID,userID,password)
trader.bind(callback.OnRspQryInstrument,OnRspQryInstrument)
data = struct.CThostFtdcQryInstrumentField()
trader.ReqQryInstrument(data)
while len(flag) == 0: sleep(.01)
df = DataFrame(result)
writer = ExcelWriter('instrument.xls')
df.to_excel(writer)
writer.save()
c1 = df['ProductID'] == 'IF'
df[c1]
# Out:
#       CreateDate  DeliveryMonth  DeliveryYear EndDelivDate ExchangeID  \
# 776     20150116              9          2015     20150918      CFFEX
# 1659    20150717              3          2016     20160318      CFFEX
# 1786    20150417             12          2015     20151218      CFFEX
# 13067   20150821             10          2015     20151016      CFFEX
#
#       ExchangeInstID ExpireDate InstLifePhase InstrumentID InstrumentName  \
# 776           IF1509   20150918             1       IF1509         股指1509
# 1659          IF1603   20160318             1       IF1603         股指1603
# 1786          IF1512   20151218             1       IF1512         股指1512
# 13067         IF1510   20151016             1       IF1510         股指1510
#
#        IsTrading  LongMarginRatio  MaxLimitOrderVolume MaxMarginSideAlgorithm  \
# 776            1              0.1                  100                      1
# 1659           1              0.1                  100                      1
# 1786           1              0.1                  100                      1
# 13067          1              0.0                  100                      0
#
#        MaxMarketOrderVolume  MinLimitOrderVolume  MinMarketOrderVolume  \
# 776                       0                    1                     1
# 1659                      0                    1                     1
# 1786                      0                    1                     1
# 13067                    50                    1                     1
#
#        OpenDate PositionDateType PositionType
# 776    20150119                2            2 ...
# 1659   20150720                2            2 ...
# 1786   20150420                2            2 ...
# 13067  20150824                2            2 ...
#
# [4 rows x 26 columns]
