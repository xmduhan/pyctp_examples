# %%
from pyctp import Trader,Md,struct,callback
from time import sleep
from pandas import DataFrame
from pandas.io.excel import ExcelWriter
from comhelper import frontAddress, brokerID, userID, password
from comhelper import wait

result = []
flag = []
def OnRspQryInstrument(**kwargs):
    result.append(kwargs['Data'])
    if kwargs['IsLast'] == True:
        flag.append(1)

trader = Trader(frontAddress,brokerID,userID,password)
trader.bind(callback.OnRspQryInstrument,OnRspQryInstrument)
data = struct.CThostFtdcQryInstrumentField()
trader.ReqQryInstrument(data)
wait(lambda: len(flag)>0)
df = DataFrame(result)
writer = ExcelWriter('instrument.xls')
df.to_excel(writer)
writer.save()
c1 = df['ProductID'] == 'IF'
df[c1]
# Out:
#      CreateDate  DeliveryMonth  DeliveryYear EndDelivDate ExchangeID  \
# 1153   20150717              3          2016     20160318      CFFEX
# 1236   20150417             12          2015     20151218      CFFEX
# 1636   20150918             11          2015     20151120      CFFEX
# 1694   20151016              6          2016     20160617      CFFEX
#
#      ExchangeInstID ExpireDate InstLifePhase InstrumentID InstrumentName  \
# 1153         IF1603   20160318             1       IF1603         股指1603
# 1236         IF1512   20151218             1       IF1512         股指1512
# 1636         IF1511   20151120             1       IF1511         股指1511
# 1694         IF1606   20160617             1       IF1606         股指1606
#
#           ...        MinMarketOrderVolume  OpenDate  PositionDateType  \
# 1153      ...                           1  20150720                 2
# 1236      ...                           1  20150420                 2
# 1636      ...                           1  20150921                 2
# 1694      ...                           1  20151019                 2
#
#      PositionType  PriceTick  ProductClass  ProductID ShortMarginRatio  \
# 1153            2        0.2             1         IF              0.4
# 1236            2        0.2             1         IF              0.4
# 1636            2        0.2             1         IF              0.4
# 1694            2        0.2             1         IF              0.4
#
#      StartDelivDate VolumeMultiple
# 1153       20160318            300
# 1236       20151218            300
# 1636       20151120            300
# 1694       20160617            300
#
# [4 rows x 26 columns]
